# %%
# !pip install bm3d
# Out:
# Collecting bm3d
#   Downloading bm3d-4.0.3-py3-none-any.whl.metadata (2.3 kB)
# Collecting bm4d>=4.2.5 (from bm3d)
#   Downloading bm4d-4.2.5-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bm4d>=4.2.5->bm3d) (1.26.4)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from bm4d>=4.2.5->bm3d) (1.13.1)
# Collecting PyWavelets (from bm4d>=4.2.5->bm3d)
#   Downloading pywavelets-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Downloading bm3d-4.0.3-py3-none-any.whl (10 kB)
# Downloading bm4d-4.2.5-py3-none-any.whl (862 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 862.0/862.0 kB 9.0 MB/s eta 0:00:00
# Downloading pywavelets-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 23.1 MB/s eta 0:00:00
# Installing collected packages: PyWavelets, bm4d, bm3d
# Successfully installed PyWavelets-1.8.0 bm3d-4.0.3 bm4d-4.2.5

# %%
# Import required libraries
import os
import csv
import bm3d
import cv2
import numpy as np
from skimage.metrics import peak_signal_noise_ratio as psnr, structural_similarity as ssim
from google.colab import drive

# Mount Google Drive to access images
drive.mount('/content/drive')

# Set input folder
input_folder = "/content/drive/MyDrive/cbsd68/original_png"  # Folder with input images
base_output_folder = "/content/drive/MyDrive/cbsd68/denoised_images"  # Base folder for denoised images
os.makedirs(base_output_folder, exist_ok=True)

# List of sigma values
sigma_values = [25, 50, 75]
batch_size = 8  # Number of images to process in each batch

def compute_metrics(clean_img, denoised_img):
    """Compute PSNR and SSIM metrics."""
    psnr_value = psnr(clean_img, denoised_img, data_range=1.0)

    min_size = min(clean_img.shape[:2])  # Adjust win_size dynamically
    win_size = min(7, min_size)
    if win_size % 2 == 0:
        win_size -= 1  # Ensure win_size is odd
    ssim_value = ssim(clean_img, denoised_img, channel_axis=2, win_size=win_size, data_range=1.0)

    return psnr_value, ssim_value

# Load all image paths from the input folder
image_paths = [os.path.join(input_folder, fname) for fname in os.listdir(input_folder) if fname.endswith(('.png', '.jpg', '.jpeg'))]

# Process images for each sigma value
for sigma in sigma_values:
    # Create a folder for the current sigma value
    output_folder = os.path.join(base_output_folder, f"sigma_{sigma}")
    os.makedirs(output_folder, exist_ok=True)

    # CSV file to store PSNR and SSIM for the current sigma
    csv_path = os.path.join(output_folder, "image_metrics.csv")
    csv_file = open(csv_path, mode='w', newline='')
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(["Image Name", "PSNR (dB)", "SSIM"])

    sigma_psd = sigma / 255.0  # Normalize sigma

    # Batch processing
    for batch_start in range(0, len(image_paths), batch_size):
        batch_end = min(batch_start + batch_size, len(image_paths))
        batch = image_paths[batch_start:batch_end]

        try:
            clean_imgs = []
            noisy_imgs = []

            # Prepare images for the batch
            for image_path in batch:
                img = cv2.imread(image_path, cv2.IMREAD_COLOR)  # Read as BGR
                img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) / 255.0  # Convert to RGB and normalize
                noisy_img = img_rgb + np.random.normal(0, sigma_psd, img_rgb.shape)
                noisy_img = np.clip(noisy_img, 0, 1)

                clean_imgs.append(img_rgb)
                noisy_imgs.append(noisy_img)

            # Apply BM3D to each image in the batch
            denoised_imgs = []
            for noisy_img in noisy_imgs:
                denoised_imgs.append(bm3d.bm3d(noisy_img, sigma_psd))

            # Compute PSNR and SSIM for the batch
            for i, (clean_img, denoised_img) in enumerate(zip(clean_imgs, denoised_imgs)):
                psnr_value, ssim_value = compute_metrics(clean_img, denoised_img)

                # Save denoised image
                denoised_img_uint8 = (denoised_img * 255).astype(np.uint8)
                image_name = f"denoised_{batch_start + i:05d}.png"
                save_path = os.path.join(output_folder, image_name)
                cv2.imwrite(save_path, cv2.cvtColor(denoised_img_uint8, cv2.COLOR_RGB2BGR))

                # Write PSNR and SSIM to CSV
                csv_writer.writerow([image_name, psnr_value, ssim_value])

                print(f"Processed image {batch_start + i + 1}/{len(image_paths)} for sigma={sigma}: PSNR={psnr_value:.2f} dB, SSIM={ssim_value:.4f}")

        except Exception as e:
            print(f"Error processing batch {batch_start} to {batch_end} for sigma={sigma}: {e}")
            continue

    # Close the CSV file for the current sigma
    csv_file.close()
    print(f"Results for sigma={sigma} saved to: {output_folder}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Processed image 1/69 for sigma=25: PSNR=32.66 dB, SSIM=0.8566
# Processed image 2/69 for sigma=25: PSNR=28.55 dB, SSIM=0.8111
# Processed image 3/69 for sigma=25: PSNR=27.47 dB, SSIM=0.8393
# Processed image 4/69 for sigma=25: PSNR=29.03 dB, SSIM=0.7842
# Processed image 5/69 for sigma=25: PSNR=28.61 dB, SSIM=0.8072
# Processed image 6/69 for sigma=25: PSNR=27.83 dB, SSIM=0.8219
# Processed image 7/69 for sigma=25: PSNR=28.95 dB, SSIM=0.8928
# Processed image 8/69 for sigma=25: PSNR=28.18 dB, SSIM=0.8507
# Processed image 9/69 for sigma=25: PSNR=24.80 dB, SSIM=0.8172
# Processed image 10/69 for sigma=25: PSNR=29.15 dB, SSIM=0.7558
# Processed image 11/69 for sigma=25: PSNR=32.12 dB, SSIM=0.8893
# Processed image 12/69 for sigma=25: PSNR=23.85 dB, SSIM=0.7635
# Processed image 13/69 for sigma=25: PSNR=29.52 dB, SSIM=0.7840
# Processed image 14/69 for sigma=25: PSNR=27.76 dB, SSIM=0.7872
# Processed image 15/69 for sigma=25: PSNR=33.04 dB, SSIM=0.8486
# Processed image 16/69 for sigma=25: PSNR=24.30 dB, SSIM=0.8378
# Processed image 17/69 for sigma=25: PSNR=31.51 dB, SSIM=0.8228
# Processed image 18/69 for sigma=25: PSNR=26.71 dB, SSIM=0.7527
# Processed image 19/69 for sigma=25: PSNR=26.27 dB, SSIM=0.7771
# Processed image 20/69 for sigma=25: PSNR=27.52 dB, SSIM=0.7693
# Processed image 21/69 for sigma=25: PSNR=31.32 dB, SSIM=0.8778
# Processed image 22/69 for sigma=25: PSNR=27.87 dB, SSIM=0.7768
# Processed image 23/69 for sigma=25: PSNR=26.87 dB, SSIM=0.7469
# Processed image 24/69 for sigma=25: PSNR=27.80 dB, SSIM=0.7520
# Processed image 25/69 for sigma=25: PSNR=30.53 dB, SSIM=0.7685
# Processed image 26/69 for sigma=25: PSNR=27.09 dB, SSIM=0.8213
# Processed image 27/69 for sigma=25: PSNR=30.06 dB, SSIM=0.8317
# Processed image 28/69 for sigma=25: PSNR=37.25 dB, SSIM=0.9510
# Processed image 29/69 for sigma=25: PSNR=30.44 dB, SSIM=0.8425
# Processed image 30/69 for sigma=25: PSNR=29.65 dB, SSIM=0.8624
# Processed image 31/69 for sigma=25: PSNR=29.85 dB, SSIM=0.7894
# Processed image 32/69 for sigma=25: PSNR=28.59 dB, SSIM=0.8982
# Processed image 33/69 for sigma=25: PSNR=31.32 dB, SSIM=0.8748
# Processed image 34/69 for sigma=25: PSNR=26.13 dB, SSIM=0.8029
# Processed image 35/69 for sigma=25: PSNR=29.24 dB, SSIM=0.8027
# Processed image 36/69 for sigma=25: PSNR=30.77 dB, SSIM=0.7379
# Processed image 37/69 for sigma=25: PSNR=28.19 dB, SSIM=0.7949
# Processed image 38/69 for sigma=25: PSNR=28.57 dB, SSIM=0.7523
# Processed image 39/69 for sigma=25: PSNR=26.30 dB, SSIM=0.6847
# Processed image 40/69 for sigma=25: PSNR=25.26 dB, SSIM=0.6903
# Processed image 41/69 for sigma=25: PSNR=27.20 dB, SSIM=0.7423
# Processed image 42/69 for sigma=25: PSNR=30.10 dB, SSIM=0.8017
# Processed image 43/69 for sigma=25: PSNR=32.39 dB, SSIM=0.8777
# Processed image 44/69 for sigma=25: PSNR=26.44 dB, SSIM=0.7852
# Processed image 45/69 for sigma=25: PSNR=26.08 dB, SSIM=0.7470
# Processed image 46/69 for sigma=25: PSNR=26.35 dB, SSIM=0.8091
# Processed image 47/69 for sigma=25: PSNR=29.26 dB, SSIM=0.7898
# Processed image 48/69 for sigma=25: PSNR=25.79 dB, SSIM=0.7519
# Processed image 49/69 for sigma=25: PSNR=26.80 dB, SSIM=0.7506
# Processed image 50/69 for sigma=25: PSNR=27.49 dB, SSIM=0.7607
# Processed image 51/69 for sigma=25: PSNR=27.86 dB, SSIM=0.7275
# Processed image 52/69 for sigma=25: PSNR=28.68 dB, SSIM=0.8079
# Processed image 53/69 for sigma=25: PSNR=23.99 dB, SSIM=0.7773
# Processed image 54/69 for sigma=25: PSNR=29.49 dB, SSIM=0.8191
# Processed image 55/69 for sigma=25: PSNR=23.44 dB, SSIM=0.7292
# Processed image 56/69 for sigma=25: PSNR=26.97 dB, SSIM=0.4466
# Processed image 57/69 for sigma=25: PSNR=27.94 dB, SSIM=0.7746
# Processed image 58/69 for sigma=25: PSNR=25.61 dB, SSIM=0.8320
# Processed image 59/69 for sigma=25: PSNR=28.31 dB, SSIM=0.8469
# Processed image 60/69 for sigma=25: PSNR=29.10 dB, SSIM=0.8494
# Processed image 61/69 for sigma=25: PSNR=28.59 dB, SSIM=0.7654
# Processed image 62/69 for sigma=25: PSNR=27.37 dB, SSIM=0.8778
# Processed image 63/69 for sigma=25: PSNR=30.59 dB, SSIM=0.7615
# Processed image 64/69 for sigma=25: PSNR=25.67 dB, SSIM=0.7114
# Processed image 65/69 for sigma=25: PSNR=28.32 dB, SSIM=0.8525
# Processed image 66/69 for sigma=25: PSNR=27.60 dB, SSIM=0.7770
# Processed image 67/69 for sigma=25: PSNR=26.27 dB, SSIM=0.7581
# Processed image 68/69 for sigma=25: PSNR=28.58 dB, SSIM=0.7655
# Processed image 69/69 for sigma=25: PSNR=29.83 dB, SSIM=0.7501
# Results for sigma=25 saved to: /content/drive/MyDrive/cbsd68/denoised_images/sigma_25
# Processed image 1/69 for sigma=50: PSNR=27.94 dB, SSIM=0.8033
# Processed image 2/69 for sigma=50: PSNR=24.82 dB, SSIM=0.6752
# Processed image 3/69 for sigma=50: PSNR=23.45 dB, SSIM=0.6993
# Processed image 4/69 for sigma=50: PSNR=25.59 dB, SSIM=0.6889
# Processed image 5/69 for sigma=50: PSNR=25.07 dB, SSIM=0.6767
# Processed image 6/69 for sigma=50: PSNR=23.46 dB, SSIM=0.6502
# Processed image 7/69 for sigma=50: PSNR=25.01 dB, SSIM=0.7823
# Processed image 8/69 for sigma=50: PSNR=23.85 dB, SSIM=0.7419
# Processed image 9/69 for sigma=50: PSNR=20.65 dB, SSIM=0.6087
# Processed image 10/69 for sigma=50: PSNR=26.08 dB, SSIM=0.6712
# Processed image 11/69 for sigma=50: PSNR=27.80 dB, SSIM=0.7972
# Processed image 12/69 for sigma=50: PSNR=19.56 dB, SSIM=0.5004
# Processed image 13/69 for sigma=50: PSNR=26.27 dB, SSIM=0.6397
# Processed image 14/69 for sigma=50: PSNR=23.74 dB, SSIM=0.6870
# Processed image 15/69 for sigma=50: PSNR=30.39 dB, SSIM=0.7761
# Processed image 16/69 for sigma=50: PSNR=20.64 dB, SSIM=0.6412
# Processed image 17/69 for sigma=50: PSNR=26.85 dB, SSIM=0.7093
# Processed image 18/69 for sigma=50: PSNR=23.14 dB, SSIM=0.5818
# Processed image 19/69 for sigma=50: PSNR=23.07 dB, SSIM=0.5597
# Processed image 20/69 for sigma=50: PSNR=24.40 dB, SSIM=0.6264
# Processed image 21/69 for sigma=50: PSNR=26.70 dB, SSIM=0.8053
# Processed image 22/69 for sigma=50: PSNR=24.47 dB, SSIM=0.6112
# Processed image 23/69 for sigma=50: PSNR=23.27 dB, SSIM=0.5894
# Processed image 24/69 for sigma=50: PSNR=23.68 dB, SSIM=0.5696
# Processed image 25/69 for sigma=50: PSNR=28.47 dB, SSIM=0.7009
# Processed image 26/69 for sigma=50: PSNR=23.18 dB, SSIM=0.6069
# Processed image 27/69 for sigma=50: PSNR=26.51 dB, SSIM=0.7335
# Processed image 28/69 for sigma=50: PSNR=32.70 dB, SSIM=0.9201
# Processed image 29/69 for sigma=50: PSNR=26.93 dB, SSIM=0.7109
# Processed image 30/69 for sigma=50: PSNR=25.30 dB, SSIM=0.7578
# Processed image 31/69 for sigma=50: PSNR=25.97 dB, SSIM=0.7273
# Processed image 32/69 for sigma=50: PSNR=23.74 dB, SSIM=0.7848
# Processed image 33/69 for sigma=50: PSNR=25.18 dB, SSIM=0.7336
# Processed image 34/69 for sigma=50: PSNR=22.30 dB, SSIM=0.5666
# Processed image 35/69 for sigma=50: PSNR=26.13 dB, SSIM=0.6754
# Processed image 36/69 for sigma=50: PSNR=28.58 dB, SSIM=0.6539
# Processed image 37/69 for sigma=50: PSNR=24.59 dB, SSIM=0.6360
# Processed image 38/69 for sigma=50: PSNR=25.08 dB, SSIM=0.5709
# Processed image 39/69 for sigma=50: PSNR=23.73 dB, SSIM=0.5126
# Processed image 40/69 for sigma=50: PSNR=21.93 dB, SSIM=0.4806
# Processed image 41/69 for sigma=50: PSNR=23.60 dB, SSIM=0.5972
# Processed image 42/69 for sigma=50: PSNR=25.81 dB, SSIM=0.7420
# Processed image 43/69 for sigma=50: PSNR=28.50 dB, SSIM=0.8016
# Processed image 44/69 for sigma=50: PSNR=22.77 dB, SSIM=0.6192
# Processed image 45/69 for sigma=50: PSNR=22.93 dB, SSIM=0.5874
# Processed image 46/69 for sigma=50: PSNR=22.93 dB, SSIM=0.5900
# Processed image 47/69 for sigma=50: PSNR=25.38 dB, SSIM=0.6462
# Processed image 48/69 for sigma=50: PSNR=22.01 dB, SSIM=0.5611
# Processed image 49/69 for sigma=50: PSNR=23.34 dB, SSIM=0.5697
# Processed image 50/69 for sigma=50: PSNR=24.82 dB, SSIM=0.6262
# Processed image 51/69 for sigma=50: PSNR=25.27 dB, SSIM=0.6034
# Processed image 52/69 for sigma=50: PSNR=23.29 dB, SSIM=0.7077
# Processed image 53/69 for sigma=50: PSNR=20.09 dB, SSIM=0.4451
# Processed image 54/69 for sigma=50: PSNR=26.31 dB, SSIM=0.6670
# Processed image 55/69 for sigma=50: PSNR=20.03 dB, SSIM=0.4023
# Processed image 56/69 for sigma=50: PSNR=26.05 dB, SSIM=0.3920
# Processed image 57/69 for sigma=50: PSNR=24.83 dB, SSIM=0.6443
# Processed image 58/69 for sigma=50: PSNR=21.24 dB, SSIM=0.6450
# Processed image 59/69 for sigma=50: PSNR=24.22 dB, SSIM=0.6988
# Processed image 60/69 for sigma=50: PSNR=25.20 dB, SSIM=0.7655
# Processed image 61/69 for sigma=50: PSNR=25.08 dB, SSIM=0.6700
# Processed image 62/69 for sigma=50: PSNR=23.68 dB, SSIM=0.7529
# Processed image 63/69 for sigma=50: PSNR=28.73 dB, SSIM=0.6861
# Processed image 64/69 for sigma=50: PSNR=21.96 dB, SSIM=0.4765
# Processed image 65/69 for sigma=50: PSNR=24.02 dB, SSIM=0.7056
# Processed image 66/69 for sigma=50: PSNR=24.02 dB, SSIM=0.6612
# Processed image 67/69 for sigma=50: PSNR=22.46 dB, SSIM=0.5728
# Processed image 68/69 for sigma=50: PSNR=25.13 dB, SSIM=0.6706
# Processed image 69/69 for sigma=50: PSNR=27.57 dB, SSIM=0.6717
# Results for sigma=50 saved to: /content/drive/MyDrive/cbsd68/denoised_images/sigma_50
# Processed image 1/69 for sigma=75: PSNR=24.11 dB, SSIM=0.7593
# Processed image 2/69 for sigma=75: PSNR=21.89 dB, SSIM=0.5764
# Processed image 3/69 for sigma=75: PSNR=20.69 dB, SSIM=0.5699
# Processed image 4/69 for sigma=75: PSNR=23.30 dB, SSIM=0.6260
# Processed image 5/69 for sigma=75: PSNR=22.60 dB, SSIM=0.5802
# Processed image 6/69 for sigma=75: PSNR=20.60 dB, SSIM=0.5291
# Processed image 7/69 for sigma=75: PSNR=22.30 dB, SSIM=0.6932
# Processed image 8/69 for sigma=75: PSNR=21.17 dB, SSIM=0.6816
# Processed image 9/69 for sigma=75: PSNR=18.52 dB, SSIM=0.5048
# Processed image 10/69 for sigma=75: PSNR=23.83 dB, SSIM=0.6266
# Processed image 11/69 for sigma=75: PSNR=24.65 dB, SSIM=0.7241
# Processed image 12/69 for sigma=75: PSNR=17.62 dB, SSIM=0.3540
# Processed image 13/69 for sigma=75: PSNR=24.25 dB, SSIM=0.5649
# Processed image 14/69 for sigma=75: PSNR=21.03 dB, SSIM=0.6249
# Processed image 15/69 for sigma=75: PSNR=28.20 dB, SSIM=0.7383
# Processed image 16/69 for sigma=75: PSNR=18.54 dB, SSIM=0.4730
# Processed image 17/69 for sigma=75: PSNR=23.37 dB, SSIM=0.6396
# Processed image 18/69 for sigma=75: PSNR=21.12 dB, SSIM=0.4844
# Processed image 19/69 for sigma=75: PSNR=21.38 dB, SSIM=0.4166
# Processed image 20/69 for sigma=75: PSNR=22.09 dB, SSIM=0.5363
# Processed image 21/69 for sigma=75: PSNR=23.32 dB, SSIM=0.7573
# Processed image 22/69 for sigma=75: PSNR=22.02 dB, SSIM=0.4780
# Processed image 23/69 for sigma=75: PSNR=20.78 dB, SSIM=0.4952
# Processed image 24/69 for sigma=75: PSNR=20.93 dB, SSIM=0.4630
# Processed image 25/69 for sigma=75: PSNR=26.75 dB, SSIM=0.6632
# Processed image 26/69 for sigma=75: PSNR=21.03 dB, SSIM=0.4745
# Processed image 27/69 for sigma=75: PSNR=24.04 dB, SSIM=0.6749
# Processed image 28/69 for sigma=75: PSNR=29.99 dB, SSIM=0.9016
# Processed image 29/69 for sigma=75: PSNR=24.61 dB, SSIM=0.6313
# Processed image 30/69 for sigma=75: PSNR=22.16 dB, SSIM=0.6725
# Processed image 31/69 for sigma=75: PSNR=22.90 dB, SSIM=0.6843
# Processed image 32/69 for sigma=75: PSNR=20.68 dB, SSIM=0.6912
# Processed image 33/69 for sigma=75: PSNR=21.27 dB, SSIM=0.6267
# Processed image 34/69 for sigma=75: PSNR=20.35 dB, SSIM=0.4268
# Processed image 35/69 for sigma=75: PSNR=24.25 dB, SSIM=0.5966
# Processed image 36/69 for sigma=75: PSNR=26.62 dB, SSIM=0.6220
# Processed image 37/69 for sigma=75: PSNR=22.12 dB, SSIM=0.5232
# Processed image 38/69 for sigma=75: PSNR=22.85 dB, SSIM=0.4862
# Processed image 39/69 for sigma=75: PSNR=22.03 dB, SSIM=0.4245
# Processed image 40/69 for sigma=75: PSNR=20.10 dB, SSIM=0.3646
# Processed image 41/69 for sigma=75: PSNR=21.40 dB, SSIM=0.5253
# Processed image 42/69 for sigma=75: PSNR=22.59 dB, SSIM=0.7026
# Processed image 43/69 for sigma=75: PSNR=25.17 dB, SSIM=0.7522
# Processed image 44/69 for sigma=75: PSNR=20.46 dB, SSIM=0.5281
# Processed image 45/69 for sigma=75: PSNR=20.94 dB, SSIM=0.4929
# Processed image 46/69 for sigma=75: PSNR=21.06 dB, SSIM=0.4372
# Processed image 47/69 for sigma=75: PSNR=22.81 dB, SSIM=0.5550
# Processed image 48/69 for sigma=75: PSNR=19.78 dB, SSIM=0.4364
# Processed image 49/69 for sigma=75: PSNR=21.17 dB, SSIM=0.4713
# Processed image 50/69 for sigma=75: PSNR=22.89 dB, SSIM=0.5668
# Processed image 51/69 for sigma=75: PSNR=23.10 dB, SSIM=0.5471
# Processed image 52/69 for sigma=75: PSNR=19.77 dB, SSIM=0.6330
# Processed image 53/69 for sigma=75: PSNR=18.53 dB, SSIM=0.2663
# Processed image 54/69 for sigma=75: PSNR=24.46 dB, SSIM=0.5799
# Processed image 55/69 for sigma=75: PSNR=18.68 dB, SSIM=0.2731
# Processed image 56/69 for sigma=75: PSNR=25.48 dB, SSIM=0.3720
# Processed image 57/69 for sigma=75: PSNR=22.59 dB, SSIM=0.5567
# Processed image 58/69 for sigma=75: PSNR=18.63 dB, SSIM=0.4769
# Processed image 59/69 for sigma=75: PSNR=21.74 dB, SSIM=0.5881
# Processed image 60/69 for sigma=75: PSNR=22.38 dB, SSIM=0.6923
# Processed image 61/69 for sigma=75: PSNR=22.65 dB, SSIM=0.5953
# Processed image 62/69 for sigma=75: PSNR=21.62 dB, SSIM=0.6618
# Processed image 63/69 for sigma=75: PSNR=27.36 dB, SSIM=0.6583
# Processed image 64/69 for sigma=75: PSNR=19.93 dB, SSIM=0.3643
# Processed image 65/69 for sigma=75: PSNR=21.11 dB, SSIM=0.5712
# Processed image 66/69 for sigma=75: PSNR=21.65 dB, SSIM=0.5756
# Processed image 67/69 for sigma=75: PSNR=19.94 dB, SSIM=0.4369
# Processed image 68/69 for sigma=75: PSNR=22.66 dB, SSIM=0.5950
# Processed image 69/69 for sigma=75: PSNR=25.39 dB, SSIM=0.6281
# Results for sigma=75 saved to: /content/drive/MyDrive/cbsd68/denoised_images/sigma_75
